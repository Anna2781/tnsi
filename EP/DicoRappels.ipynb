# %% [markdown]
# # Rappels sur les dictionnaires

# %% [markdown]
# a) Créer un dictionnaire vide : `d`

# %% [markdown]
# b) Ajouter dans `d` la clé `1` et la valeur `'One'`

# %% [markdown]
# c) Ajouter dans `d` la clé `2` et la valeur `'Deux'`

# %% [markdown]
# d) Ajouter dans `d` la clé `3` et la valeur `'Trois'`

# %% [markdown]
# e) modifier la valeur correspondant à la clé `1` pour qu'elle devienne `Un`

# %% [markdown]
# f) Compléter le code suivant pour que l'exécution de la cellule affiche :
#
#     1
#     2
#     3

# %%
for ... in d : 
    print (...)

# %% [markdown]
# g) Compléter le code suivant pour que l'exécution de la cellule affiche :
#
#     Un
#     Deux
#     Trois

# %%
for ... in d : 
    print (...)

# %% [markdown]
# h) Compléter le code suivant pour que l'exécution de la cellule affiche :
#
#     1 Un
#     2 Deux
#     3 Trois

# %%
for k,v in ...  : 
    print (k,v)
