# %% [markdown]
# ## Exercice 5

# %%
class Maillon:  
    def __init__(self, val, suiv=None):
        self.valeur = val
        self.suivant = suiv

    def __str__(self):
        if self is None:
            return ''
        if self.suivant is None:
            return str(self.valeur)
        return str(self.valeur) + '-' + str(self.suivant)

# %%
lst = Maillon(10,Maillon(20))

# %% [markdown]
# Ecrire les instructions permettant d'insérer un maillon de valeur 15 entre ceux de valeurs 10 et 20.
# Une fois ces instructions exécutées, `print(lst)` doit donner `10-15-20`
