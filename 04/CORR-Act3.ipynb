# %% [markdown]
# # Correction de l'activité 3

# %% [markdown]
# On reprend la classe Maillon de l'activité 1, et on définit une fonction `mystere`

# %%
class Maillon:  
    def __init__(self, val, suiv=None):
        self.valeur = val
        self.suivant = suiv

def mystere(lst, n):
    if n == 0:
        return lst.valeur
    else:
        return mystere(lst.suivant, n-1)

# %% [markdown]
# ## Pour chacune des trois cellules suivantes :
# * Déterminer ce qui sera affiché à l'éxécution du code suivant,
# * puis vérifier en exécutant la cellule :

# %% [markdown]
# ### Exemple 1

# %%
lst = Maillon(30, Maillon(20, Maillon(10)))
x = mystere(lst, 0)
print(x)
# Out:
# 30

# %% [markdown]
# ### Exemple 2

# %%
lst = Maillon(50, Maillon(60, Maillon(70)))
y = mystere(lst, 2)
print(y)
# Out:
# 70

# %% [markdown]
# ### Exemple 3

# %%
lst = Maillon(1, Maillon(2, Maillon(3)))
z = mystere(lst, 3)
print(z)
# Out:
# Traceback (most recent call last):
#   File "<input>", line 2, in <module>
#   File "<input>", line 10, in mystere
#   File "<input>", line 10, in mystere
#   File "<input>", line 10, in mystere
#   File "<input>", line 8, in mystere
# AttributeError: 'NoneType' object has no attribute 'valeur'
# Error:

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# 1. Expliquer le rôle de la fonction mystere
#
# #### réponse :
# la fonction mystère donne la valeur du maillon de rang 'n' dans la chaîne lst
#
# 2. Améliorer la définition de la fonction mystere, pour qu'un message d'erreur plus explicite soit levé dans le cas rencontré dans l'exemple 3.

# %%
def mystere(lst, n):
    # ajout d' assertions
    assert n >= 0 , "n doit être positif"
    assert  lst is not None , "indice n trop grand"
        
    if n == 0:
        return lst.valeur
    else:
        return mystere(lst.suivant, n-1)

# %%
lst = Maillon(1, Maillon(2, Maillon(3)))
z = mystere(lst, 3)
print(z)
# Out:
# Traceback (most recent call last):
#   File "<input>", line 2, in <module>
#   File "<input>", line 9, in mystere
#   File "<input>", line 9, in mystere
#   File "<input>", line 9, in mystere
#   File "<input>", line 4, in mystere
# AssertionError: indice n trop grand
# Error:

# %% [markdown]
# On a une erreur plus "lisible" : c'est la valeur du paramètre n qui est incorrecte, dans le dernier cas.
